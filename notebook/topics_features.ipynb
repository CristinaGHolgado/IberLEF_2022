# %%
import pandas as pd

# %%
df = pd.read_csv("../data/training_topics.tsv", sep='\t')
df
# Out:
#         label  gender  profession ideology_binary ideology_multiclass  \
# 0      @user1    male  politician            left       moderate_left
# 1     @user10    male  journalist           right      moderate_right
# 2    @user100  female  politician            left       moderate_left
# 3    @user105    male  politician            left       moderate_left
# 4    @user106    male  politician           right      moderate_right
# ..        ...     ...         ...             ...                 ...
# 309   @user95    male  politician            left       moderate_left
# 310   @user96  female  politician           right      moderate_right
# 311   @user97  female  politician            left       moderate_left
# 312   @user98    male  journalist            left                left
# 313   @user99    male  politician            left                left
#
#             1         2         3         4         5  ...        11  \
# ...

# %%
Xtrain = df.iloc[:,5:].to_numpy()

# %%
from sklearn.model_selection import train_test_split

# %%
from tqdm import tqdm

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, f1_score


scores = []
for i in tqdm(range(100)):
    xtrain, xtest, ytrain, ytest = train_test_split(Xtrain, df.ideology_multiclass)
    m = SVC(class_weight='balanced')

    m.fit(xtrain, ytrain)
    predictions = m.predict(xtest)
    cm =confusion_matrix(ytest, predictions)
    cr = classification_report(ytest, predictions, zero_division = 0, output_dict=True
                              )
    score = cr['weighted avg']['f1-score']
    scores.append(score)
print(cm)
print(cr)
#print()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 149.44it/s]
# [[14  2  1  4]
#  [ 2 19  2  2]
#  [ 2  8  8  6]
#  [ 3  3  0  3]]
# {'left': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 21}, 'moderate_left': {'precision': 0.59375, 'recall': 0.76, 'f1-score': 0.6666666666666666, 'support': 25}, 'moderate_right': {'precision': 0.7272727272727273, 'recall': 0.3333333333333333, 'f1-score': 0.4571428571428572, 'support': 24}, 'right': {'precision': 0.2, 'recall': 0.3333333333333333, 'f1-score': 0.25, 'support': 9}, 'accuracy': 0.5569620253164557, 'macro avg': {'precision': 0.5469223484848484, 'recall': 0.5233333333333333, 'f1-score': 0.5101190476190476, 'support': 79}, 'weighted avg': {'precision': 0.6088391829689298, 'recall': 0.5569620253164557, 'f1-score': 0.5555455093429776, 'support': 79}}

# %%
import numpy as np

# %%
'gender', np.mean(scores), '+/-', np.std(scores)
# Out:
# ('gender', 0.6611775189797916, '+/-', 0.047955783134448426)

# %%
'profession', np.mean(scores), '+/-', np.std(scores)
# Out:
# ('profession', 0.8738187657485981, '+/-', 0.031143091896702432)

# %%
'ideology_binary', np.mean(scores), '+/-', np.std(scores)
# Out:
# ('ideology_binary', 0.8055136349621734, '+/-', 0.04074404397697279)

# %%
'ideology_multi', np.mean(scores), '+/-', np.std(scores)
# Out:
# ('ideology_multi', 0.6223828528326054, '+/-', 0.04505287664056626)
